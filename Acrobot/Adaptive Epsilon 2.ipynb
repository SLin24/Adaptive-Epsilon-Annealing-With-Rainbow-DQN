# %%
from torch import nn
import torch
import gym
from collections import deque
import itertools
import numpy as np
import random
import wandb

BATCH_SIZE=32
GAMMA=0.999
BUFFER_SIZE=10000
MIN_REPLAY_SIZE=200
EPSILON_INITIAL=0.8
EPSILON_FINAL=0.0001
epsilon = EPSILON_INITIAL
EPSILON_DECAY=25000
BETA_INITIAL=0.4
BETA_FINAL=1.0
BETA_STEPS=40000
TARGET_UPDATE=75
LEARNING_RATE=0.0003
LOG_INTERVAL=1000
LOG_DIR = './logs'

use_duel = True
use_double = True
use_priority = True
use_multi_step = True

# %%
class Network(nn.Module):
    def __init__(self, env):
        super().__init__()
        inputLayer = int(np.prod(env.observation_space.shape))
        self.feature_layer = nn.Sequential(nn.Linear(inputLayer, 128),
                                          nn.ReLU(),
                                          nn.Linear(128, 128),
                                          nn.ReLU())
        self.value_stream = nn.Sequential(nn.Linear(128, 128),
                                         nn.ReLU(),
                                         nn.Linear(128,1))
        self.advantage_stream = nn.Sequential(nn.Linear(128, 128),
                                             nn.ReLU(),
                                             nn.Linear(128, env.action_space.n))
        self.importance_weights = torch.FloatTensor()
        self.net = nn.Sequential(nn.Linear(inputLayer, 64),
                                nn.Tanh(),
                                nn.Linear(64, env.action_space.n))
    def forward(self, x):
        if (use_duel):
            features = self.feature_layer(x)
            value = self.value_stream(features)
            advantage = self.advantage_stream(features)
            Q_vals = value + advantage - advantage.mean();
            return Q_vals
        else:
            return self.net(x)
    
    def act(self, obs):
        obs_t = torch.as_tensor(obs, dtype=torch.float32)
        Q_vals = self(obs_t.unsqueeze(0))
        index = torch.argmax(Q_vals, dim=1)[0]
        action = index.detach().item()
        
        rnd = random.random()
        randomAction = False
        if (rnd <= epsilon):
            randomAction = True
            action = env.action_space.sample()

        return action, randomAction
    
class Buffer(object):
    def __init__(self, size):
        self.bufferSize = size
        self.buffer = deque(maxlen=size)
        self.priorities = deque(maxlen=size)
        
    def add_experience(self, experience):
        self.buffer.append(experience)
        self.priorities.append(max(self.priorities, default=1))
    
    def get_weights(self, sample_probabilities):
        weights = 1.0 / len(self.buffer) * 1.0 / sample_probabilities
        normalized_weights = weights / max(weights)
        return weights
        
        
    def get_probabilities(self, priority_scale):
        scaled_priorities = np.array(self.priorities) ** priority_scale
        sample_probabilities = scaled_priorities / sum(scaled_priorities)
        return sample_probabilities
    
    def set_priorities(self, indices, errors, offset=0.1):
        for i,e, in zip(indices, errors):
            self.priorities[i] = (float)(abs(e) + offset)
        
    
    def sample(self, batch_size, priority_scale=1.0):
        if (use_priority):
            sample_probabilities = self.get_probabilities(priority_scale)
            sample_indices = np.random.choice(range(len(self.buffer)), size=batch_size, replace=False, p=sample_probabilities)
            samples = np.array(self.buffer)[sample_indices]
            weights = self.get_weights(sample_probabilities[sample_indices])
            return samples, weights, sample_indices
        else:
            weights = np.empty(len(self.buffer))
            weights.fill(1.0)
            indices = range(len(self.buffer))
            return random.sample(self.buffer, batch_size), weights, indices
    
    def clear(self):
        self.buffer.clear()

# %%
env = gym.make('Acrobot-v1')
wandb.init(project="performanceViewer", dir=LOG_DIR)
replay_buffer = Buffer(BUFFER_SIZE)
reward_buffer = deque()
recent_reward_buffer = deque(maxlen=50)

eps_reward = 0

target_network = Network(env)
online_network = Network(env)

target_network.load_state_dict(dict(online_network.state_dict()))

optimizer = torch.optim.Adam(online_network.parameters(), LEARNING_RATE)

obs = env.reset()[0]

for i in range(MIN_REPLAY_SIZE):
    action = env.action_space.sample()
    
    new_obs, reward, terminated, truncated, info = env.step(action)
    transition = (obs, action, reward, terminated, truncated, new_obs, True)
    replay_buffer.add_experience(transition)
    obs = new_obs
    
    if (terminated or truncated):
        obs = env.reset()[0]
        
obs = env.reset()[0]

for step in itertools.count():
    action, randomAction = online_network.act(obs)
    new_obs, reward, terminated, truncated, info = env.step(action)
    transition = (obs, action, reward, terminated, truncated, new_obs, randomAction)
    replay_buffer.add_experience(transition)
    obs = new_obs
    eps_reward += reward
    
    if terminated or truncated:
        obs = env.reset()[0]
        reward_buffer.append(eps_reward)
        recent_reward_buffer.append(eps_reward)
        eps_reward = 0.0

    transitions, weights, indices = replay_buffer.sample(BATCH_SIZE)

    observations = np.asarray([s[0] for s in transitions])
    actions = np.asarray([s[1] for s in transitions])
    rewards = np.asarray([s[2] for s in transitions])
    terminal_states = np.asarray([s[3] for s in transitions])
    new_observations = np.asarray([s[5] for s in transitions])
    random_chosen = np.asarray([s[6] for s in transitions])
    
    amt = random_chosen.sum()
    epsilon = amt / 32 * np.interp(step, [0, EPSILON_DECAY], [EPSILON_INITIAL, EPSILON_FINAL]) + EPSILON_FINAL

    observations_t = torch.as_tensor(observations, dtype=torch.float32)
    actions_t = torch.as_tensor(actions, dtype=torch.int64).unsqueeze(-1)
    rewards_t = torch.as_tensor(rewards, dtype=torch.float32).unsqueeze(-1)
    terminal_states_t = torch.as_tensor(terminal_states, dtype=torch.float32).unsqueeze(-1)
    new_observations_t = torch.as_tensor(new_observations, dtype=torch.float32)
   
    
    
    with torch.no_grad():
        if use_double:
            target_online_Q_vals = online_network(new_observations_t)
            best_indices = target_online_Q_vals.argmax(dim=1, keepdim=True)
            targets_target_Q_vals = target_network(new_observations_t)
            targets_selected_Q_vals = torch.gather(input=targets_target_Q_vals, dim=1, index=best_indices)
            targets = rewards_t + GAMMA * (1 - terminal_states_t) * targets_selected_Q_vals
            
        else:
            target_Q_vals = target_network(new_observations_t)
            max_target_Q_vals = target_Q_vals.max(dim=1, keepdim=True)[0]

            targets = rewards_t + GAMMA * (1 - terminal_states_t) * max_target_Q_vals
    
    Q_vals = online_network(observations_t)
    action_Q_vals = torch.gather(input=Q_vals, dim=1, index=actions_t)
    
#     loss = nn.functional.smooth_l1_loss(action_Q_vals, targets)
    beta = np.interp(step, [0, BETA_STEPS], [BETA_INITIAL, BETA_FINAL])
    error = targets - action_Q_vals
    loss = nn.functional.mse_loss(action_Q_vals, targets)
    
    with torch.no_grad():
        weight = sum(np.multiply(weights, loss.data.numpy()))
    if (not use_priority):
        weight = 1
    loss *= (weight**beta)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    replay_buffer.set_priorities(indices, error)
    
    if (step % TARGET_UPDATE == 0):
        target_network.load_state_dict(online_network.state_dict())
    if (step % LOG_INTERVAL == 0):
        print()
        print('STEP', step)
        print('Avg Reward: ', np.mean(reward_buffer))
        print("RECENT SIZE: ", len(recent_reward_buffer), " AVG SIZE: ", len(reward_buffer))
        wandb.log({"EPSILON": epsilon},commit=False)
        wandb.log({"EPSILON_DECAY": EPSILON_DECAY}, commit=False)
        wandb.log({"Recent Reward": np.mean(recent_reward_buffer)}, commit=False)
        wandb.log({"Current Step": step}, commit=False)
        wandb.log({"EPISODE": len(reward_buffer)}, commit=False)
        wandb.log({"Average Reward": np.mean(reward_buffer)}, commit=True)
        

env.close()
# Out:
# Finishing last run (ID:tw2pk6lg) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Average Reward</td><td> ▁▁▁▁▁█</td></tr><tr><td>Current Step</td><td>▁▂▃▅▆▇█</td></tr><tr><td>EPISODE</td><td>▁▂▃▅▆▇█</td></tr><tr><td>EPSILON</td><td>█▄▃▂▃▂▁</td></tr><tr><td>EPSILON_DECAY</td><td>▁▁▁▁▁▁▁</td></tr><tr><td>Recent Reward</td><td> ▁▁▁▁▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Average Reward</td><td>-490.91667</td></tr><tr><td>Current Step</td><td>6000</td></tr><tr><td>EPISODE</td><td>12</td></tr><tr><td>EPSILON</td><td>0.22811</td></tr><tr><td>EPSILON_DECAY</td><td>25000</td></tr><tr><td>Recent Reward</td><td>-490.91667</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rare-hill-143</strong> at: <a href='https://wandb.ai/slin25x/performanceViewer/runs/tw2pk6lg' target="_blank">https://wandb.ai/slin25x/performanceViewer/runs/tw2pk6lg</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./logs\wandb\run-20230713_190126-tw2pk6lg\logs</code>
# Successfully finished last run (ID:tw2pk6lg). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01693333333338766, max=1.0)…
# wandb version 0.15.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.4
# Run data is saved locally in <code>./logs\wandb\run-20230713_190351-cm3dqb4u</code>
# Syncing run <strong><a href='https://wandb.ai/slin25x/performanceViewer/runs/cm3dqb4u' target="_blank">usual-deluge-144</a></strong> to <a href='https://wandb.ai/slin25x/performanceViewer' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/slin25x/performanceViewer' target="_blank">https://wandb.ai/slin25x/performanceViewer</a>
#  View run at <a href='https://wandb.ai/slin25x/performanceViewer/runs/cm3dqb4u' target="_blank">https://wandb.ai/slin25x/performanceViewer/runs/cm3dqb4u</a>
# C:\Users\S.Lin25\AppData\Local\Temp\ipykernel_10488\1971713383.py:74: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   samples = np.array(self.buffer)[sample_indices]
# AMT 32
#
# STEP 0
# Avg Reward:  nan
# RECENT SIZE:  0  AVG SIZE:  0
# AMT 20
#
# STEP 1000
# Avg Reward:  -500.0
# RECENT SIZE:  2  AVG SIZE:  2
# AMT 22
#
# STEP 2000
# Avg Reward:  -500.0
# RECENT SIZE:  4  AVG SIZE:  4
# AMT 12
#
# STEP 3000
# Avg Reward:  -478.8333333333333
# RECENT SIZE:  6  AVG SIZE:  6
# AMT 13
#
# STEP 4000
# Avg Reward:  -425.1111111111111
# RECENT SIZE:  9  AVG SIZE:  9
# AMT 11
#
# STEP 5000
# Avg Reward:  -329.06666666666666
# RECENT SIZE:  15  AVG SIZE:  15
# AMT 9
#
# STEP 6000
# Avg Reward:  -255.34782608695653
# RECENT SIZE:  23  AVG SIZE:  23
# AMT 11
#
# STEP 7000
# Avg Reward:  -245.92857142857142
# RECENT SIZE:  28  AVG SIZE:  28
# AMT 6
#
# STEP 8000
# Avg Reward:  -220.69444444444446
# RECENT SIZE:  36  AVG SIZE:  36
# AMT 8
#
# STEP 9000
# Avg Reward:  -207.3953488372093
# RECENT SIZE:  43  AVG SIZE:  43
# AMT 10
#
# STEP 10000
# Avg Reward:  -187.33962264150944
# RECENT SIZE:  50  AVG SIZE:  53
# AMT 9
#
# STEP 11000
# Avg Reward:  -175.19354838709677
# RECENT SIZE:  50  AVG SIZE:  62
# AMT 9
#
# STEP 12000
# Avg Reward:  -164.68055555555554
# RECENT SIZE:  50  AVG SIZE:  72
# AMT 3
#
# STEP 13000
# Avg Reward:  -156.390243902439
# RECENT SIZE:  50  AVG SIZE:  82
# AMT 3
#
# STEP 14000
# Avg Reward:  -148.90322580645162
# RECENT SIZE:  50  AVG SIZE:  93
# AMT 4
#
# STEP 15000
# Avg Reward:  -144.88
# RECENT SIZE:  50  AVG SIZE:  100
# AMT 2
#
# STEP 16000
# Avg Reward:  -147.0
# RECENT SIZE:  50  AVG SIZE:  108
# AMT 3
#
# STEP 17000
# Avg Reward:  -142.4957264957265
# RECENT SIZE:  50  AVG SIZE:  117
# AMT 4
#
# STEP 18000
# Avg Reward:  -141.4206349206349
# RECENT SIZE:  50  AVG SIZE:  126
# AMT 3
#
# STEP 19000
# Avg Reward:  -137.20437956204378
# RECENT SIZE:  50  AVG SIZE:  137
# AMT 4
#
# STEP 20000
# Avg Reward:  -133.88513513513513
# RECENT SIZE:  50  AVG SIZE:  148
# AMT 4
#
# STEP 21000
# Avg Reward:  -130.30625
# RECENT SIZE:  50  AVG SIZE:  160
# AMT 1
#
# STEP 22000
# Avg Reward:  -127.33333333333333
# RECENT SIZE:  50  AVG SIZE:  171
# AMT 3
#
# STEP 23000
# Avg Reward:  -124.62841530054645
# RECENT SIZE:  50  AVG SIZE:  183
# AMT 0
#
# STEP 24000
# Avg Reward:  -123.00518134715026
# RECENT SIZE:  50  AVG SIZE:  193
# AMT 0
#
# STEP 25000
# Avg Reward:  -123.73
# RECENT SIZE:  50  AVG SIZE:  200
# AMT 0
#
# STEP 26000
# Avg Reward:  -122.12796208530806
# RECENT SIZE:  50  AVG SIZE:  211
# AMT 0
#
# STEP 27000
# Avg Reward:  -120.42792792792793
# RECENT SIZE:  50  AVG SIZE:  222
# AMT 1
#
# STEP 28000
# Avg Reward:  -118.46581196581197
# RECENT SIZE:  50  AVG SIZE:  234
# AMT 0
#
# STEP 29000
# Avg Reward:  -116.6869918699187
# RECENT SIZE:  50  AVG SIZE:  246
# AMT 0
#
# STEP 30000
# Avg Reward:  -115.23643410852713
# RECENT SIZE:  50  AVG SIZE:  258
# AMT 0
#
# STEP 31000
# Avg Reward:  -113.70370370370371
# RECENT SIZE:  50  AVG SIZE:  270
# AMT 0
#
# STEP 32000
# Avg Reward:  -113.06071428571428
# RECENT SIZE:  50  AVG SIZE:  280
# AMT 0
#
# STEP 33000
# Avg Reward:  -112.98961937716263
# RECENT SIZE:  50  AVG SIZE:  289
# AMT 0
#
# STEP 34000
# Avg Reward:  -111.61461794019934
# RECENT SIZE:  50  AVG SIZE:  301
# AMT 0
#
# STEP 35000
# Avg Reward:  -110.92948717948718
# RECENT SIZE:  50  AVG SIZE:  312
# AMT 0
#
# STEP 36000
# Avg Reward:  -109.91975308641975
# RECENT SIZE:  50  AVG SIZE:  324
# AMT 0
#
# STEP 37000
# Avg Reward:  -108.97321428571429
# RECENT SIZE:  50  AVG SIZE:  336
# AMT 0
#
# STEP 38000
# Avg Reward:  -108.51585014409221
# RECENT SIZE:  50  AVG SIZE:  347
# AMT 0
#
# STEP 39000
# Avg Reward:  -109.00282485875707
# RECENT SIZE:  50  AVG SIZE:  354
# AMT 0
#
# STEP 40000
# Avg Reward:  -108.4958904109589
# RECENT SIZE:  50  AVG SIZE:  365
# AMT 0
#
# STEP 41000
# Avg Reward:  -107.43386243386243
# RECENT SIZE:  50  AVG SIZE:  378
# AMT 0
#
# STEP 42000
# Avg Reward:  -106.43478260869566
# RECENT SIZE:  50  AVG SIZE:  391
# AMT 0
#
# STEP 43000
# Avg Reward:  -105.98507462686567
# RECENT SIZE:  50  AVG SIZE:  402
# AMT 0
#
# STEP 44000
# Avg Reward:  -105.92214111922141
# RECENT SIZE:  50  AVG SIZE:  411
# AMT 0
#
# STEP 45000
# Avg Reward:  -105.66666666666667
# RECENT SIZE:  50  AVG SIZE:  420
# AMT 0
#
# STEP 46000
# Avg Reward:  -105.87209302325581
# RECENT SIZE:  50  AVG SIZE:  430
# AMT 0
#
# STEP 47000
# Avg Reward:  -105.10835214446952
# RECENT SIZE:  50  AVG SIZE:  443
# AMT 0
#
# STEP 48000
# Avg Reward:  -104.4
# RECENT SIZE:  50  AVG SIZE:  455
# AMT 0
#
# STEP 49000
# Avg Reward:  -103.70299145299145
# RECENT SIZE:  50  AVG SIZE:  468
# AMT 0
#
# STEP 50000
# Avg Reward:  -103.39665970772442
# RECENT SIZE:  50  AVG SIZE:  479
# AMT 0
#
# STEP 51000
# Avg Reward:  -102.95510204081633
# RECENT SIZE:  50  AVG SIZE:  490
# AMT 0
#
# STEP 52000
# Avg Reward:  -102.1765873015873
# RECENT SIZE:  50  AVG SIZE:  504
# AMT 0
#
# STEP 53000
# Avg Reward:  -101.66666666666667
# RECENT SIZE:  50  AVG SIZE:  516
# AMT 0
#
# STEP 54000
# Avg Reward:  -101.06238185255198
# RECENT SIZE:  50  AVG SIZE:  529
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 64
#      61 epsilon = amt / 32 * np.interp(step, [0, EPSILON_DECAY], [EPSILON_INITIAL, EPSILON_FINAL]) + EPSILON_FINAL
#      63 observations_t = torch.as_tensor(observations, dtype=torch.float32)
# ---> 64 actions_t = torch.as_tensor(actions, dtype=torch.int64).unsqueeze(-1)
#      65 rewards_t = torch.as_tensor(rewards, dtype=torch.float32).unsqueeze(-1)
#      66 terminal_states_t = torch.as_tensor(terminal_states, dtype=torch.float32).unsqueeze(-1)
#
# KeyboardInterrupt:
